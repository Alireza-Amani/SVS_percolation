# %% [markdown]
# This notebook hosts the `SVSPaper` class, which takes care of the entire
# pipeline of the data treatment and simulation done for the SVS paper.
#
# Before running this notebook, make sure you have modified (if needed) the values
# of variables inside the `provide_information.py` file.

# %%
# <<< imports >>> -----------------------------------------------------------
from provide_information import SVSPaper

# ___________________________________________________________________ <<< >>>

# <<< variable definition >>> -----------------------------------------------



# ___________________________________________________________________ <<< >>>

# <<< main >>> --------------------------------------------------------------

# create an instance of the SVSPaper class
svs_paper2 = SVSPaper()


if __name__ == "__main__":

    # takes care of fitting the SWRC equation to the HYPROP data
    # determines the parameters for the SWRC equation and other related params
    svs_paper2.get_swrc_params()

    # creates the perturbed metfiles
    svs_paper2.create_perturbed_metfiles(use_previous=False)

    # create the base params for the enclosures
    svs_paper2.create_base_params_for_enclosures(True)
    
    # create the perturbed params for the enclosures
    svs_paper2.create_ensembles()

    # run the perturbed enclosures
    svs_paper2.run_ensembles(save_name="ens_out_test.csv")

# ___________________________________________________________________ <<< >>>

# <<< output >>> ------------------------------------------------------------


# ___________________________________________________________________ <<< >>>
# Out:
# --------------------------------------------------------------------------------
# Running the ensemble for enclosure E1...
#
# the SVS instance modified based on scenario scn_0.
#
# the SVS instance modified based on scenario scn_1.
#
# the SVS instance modified based on scenario scn_2.
#
# the SVS instance modified based on scenario scn_3.
#
# the SVS instance modified based on scenario scn_4.
#
# Running scn_0 SVS instance ...
#
# Running scn_1 SVS instance ...
#
# Running scn_2 SVS instance ...
#
# Running scn_3 SVS instance ...
#
# Running scn_4 SVS instance ...
#
# Waiting for the last 5 process(es) to finish ...
# Finished!
#
#
# --------------------------------------------------------------------------------
# Running the ensemble for enclosure E2...
#
# the SVS instance modified based on scenario scn_0.
#
# the SVS instance modified based on scenario scn_1.
#
# the SVS instance modified based on scenario scn_2.
#
# the SVS instance modified based on scenario scn_3.
#
# ...
